# %% [markdown]
# # COGS 109 — Final Project Workbook
# ## Predicting Depression Risk from Lifestyle and Workplace Factors
#
# **Team members:** Veeratat K., Valerie Robles, George Robin
# **Date:** May 2026
#
# ---
# > 💡 **How to use this notebook:** Each section has a checklist of steps. Work through them in order. Check off each step as you complete it!

# %% [markdown]
# ---
# ## Section 0 — Setup & Imports
#
# **Steps:**
# - [ ] Import all libraries you think you will need (numpy, pandas, matplotlib, sklearn, etc.)
# - [ ] Set a random seed for reproducibility
# - [ ] Print a confirmation message so you know everything imported correctly

# %%
# YOUR CODE HERE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os # Added import for os module

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,
    classification_report
)

import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print("All imports successful!")
# Out:
# All imports successful!

# %% [markdown]
# ---
# ## Section 1 — Load & Explore the Data
#
# **Steps:**
# - [x] Download the dataset from Kaggle and upload it to Colab
# - [x] Load the CSV into a pandas DataFrame
# - [x] Print the shape — how many rows (n) and columns (p+1) are there?
# - [x] Look at the first few rows with `.head()`
# - [x] Check column names and data types with `.info()`
# - [x] Check for missing values with `.isnull().sum()`
# - [x] Check class balance — how many depressed vs not depressed?
# - [ ] Make at least one plot (e.g. boxplots of key features by depression status)
#
# > 📝 **Note for report:** Write down the final n and p here so you can paste it into your Introduction.

# %% [markdown]
# Dataset
# - https://www.kaggle.com/datasets/ikynahidwin/depression-professional-dataset/data
# - https://www.kaggle.com/datasets/hopesb/student-depression-dataset?utm_source=chatgpt.com

# %%
# Step: Load the data
# Dataset: 1
# Depression-professional-dataset
path_1 = "/content/drive/MyDrive/Colab_Notebooks/Depression_Professional_Dataset.csv"

df_prof = pd.read_csv(path_1)

print(f"Dataset shape: {df_prof.shape}")
display(df_prof.head(10))
else:
    print(f"Error: File not found at {path_1}. Please upload the 'Depression_Professional_Dataset.csv' file to this location.")
# Out:
# Error: File not found at /content/drive/MyDrive/Colab_Notebooks/Depression_Professional_Dataset.csv. Please upload the 'Depression_Professional_Dataset.csv' file to this location.

# %%
df_prof.info()
df_prof.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1768/3552424516.py in <cell line: 0>()
# ----> 1 df_prof.info()
#       2 df_prof.isnull().sum()
#
# NameError: name 'df_prof' is not defined

# %%
# Step: Load the data
# Dataset: 2
# Student-Depression-dataset
path_2 = "/content/drive/MyDrive/Colab_Notebooks/Student_Depression_Dataset.csv"

if os.path.exists(path_2):
    df_student = pd.read_csv(path_2)  # update filename as needed
    print(f'Dataset shape: {df_student.shape}')  # (n observations, p+1 columns)
    display(df_student.head(10))
else:
    print(f"Error: File not found at {path_2}. Please upload the 'Student_Depression_Dataset.csv' file to this location.")
# Out:
# Error: File not found at /content/drive/MyDrive/Colab_Notebooks/Student_Depression_Dataset.csv. Please upload the 'Student_Depression_Dataset.csv' file to this location.

# %%
df_student.info()
df_student.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1768/2802328110.py in <cell line: 0>()
# ----> 1 df_student.info()
#       2 df_student.isnull().sum()
#
# NameError: name 'df_student' is not defined

# %%
# Explore dataset columns
prof_col = df_prof.columns.tolist()
print("Professor Depression Columns",prof_col)
student_col = df_student.columns.tolist()
print("Student Depression Columns",student_col)

# %%
# Step: Explore the data (shape, info, missing values, class balance)
df_prof_cleanup = pd.DataFrame({
    'Gender': df_prof['Gender'],
    'Age': df_prof['Age'],
    'Work_Pressure' : df_prof['Work Pressure'],
    'Job_Satisfaction' : df_prof['Job Satisfaction'],
    'Sleep_Duration' : df_prof['Sleep Duration'],
    'Dietary_Habits' : df_prof['Dietary Habits'],
    'Suicidal_Thoughts' : df_prof['Have you ever had suicidal thoughts ?'],
    'Work_Hours' : df_prof['Work Hours'],
    'Financial_Stress' : df_prof['Financial Stress'],
    'Family_History_of_Mental_Illness' : df_prof['Family History of Mental Illness'],
    'Depression' : df_prof['Depression'],
    'Source' : 'Professional'
})
df_prof_cleanup.head()

# %%
df_student_cleanup = pd.DataFrame({
    'Gender': df_student['Gender'],
    'Age': df_student['Age'],
    'Work_Pressure' : df_student['Work Pressure'],
    'Job_Satisfaction' : df_student['Job Satisfaction'],
    'Sleep_Duration' : df_student['Sleep Duration'],
    'Dietary_Habits' : df_student['Dietary Habits'],
    'Suicidal_Thoughts' : df_student['Have you ever had suicidal thoughts ?'],
    'Work_Hours' : df_student['Work/Study Hours'],
    'Financial_Stress' : df_student['Financial Stress'],
    'Family_History_of_Mental_Illness' : df_student['Family History of Mental Illness'],
    'Depression' : df_student['Depression'],
    'Source' : 'Student'
})
df_student_cleanup.head()

# %% [markdown]
# # **Merging 2 datasets**

# %%
df_merg_ps = pd.concat([df_prof_cleanup, df_student_cleanup])
print("Merged 2 dataset:", df_merg_ps.shape)
print("Observations: n =",df_merg_ps.shape[0])
print("Predictor: p =",df_merg_ps.shape[1]-2) # Excluding "Depression" and "Source"
# "Depression" is (y) or "target variable"
# "Source" is "naming the colume"

# %%
# Step: Plot feature distributions (Figure 1)
# Tip: boxplots grouped by depression status work well here
# Remember to label axes and add a title!
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 2 — Preprocessing
#
# **Steps:**
# - [ ] Handle missing values (drop rows, or impute — explain your choice)
# - [ ] Encode categorical columns using one-hot encoding
# - [ ] Separate features (X) from the target variable (y)
# - [ ] Standardize / scale the features (important for KNN and Logistic Regression!)
# - [ ] Print the final shape of X and confirm p
#
# > ⚠️ **Important:** Fit the scaler on X only — not on y.

# %%
# Step: Handle missing values
# YOUR CODE HERE

# %%
# Step: One-hot encode categorical columns
# YOUR CODE HERE

# %%
# Step: Define X and y, then standardize X
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 3 — Model Selection (Cross-Validation)
#
# **Steps:**
# - [ ] Set up a 5-fold stratified cross-validator (shuffle=True, set random_state)
# - [ ] Train and evaluate **Logistic Regression** using cross-validation → record mean & std accuracy
# - [ ] Train and evaluate **KNN for k = 1, 3, 5, 7, 10, 15, 20, 25, 30** → record mean & std for each k
# - [ ] Identify the best k for KNN (highest CV accuracy)
# - [ ] Plot CV accuracy vs k, with logistic regression shown as a horizontal dashed line (Figure 2)
# - [ ] Make a bar chart comparing the best KNN vs logistic regression (Figure 2b)
# - [ ] Discuss: which k values overfit? which underfit? which model wins?
#
# > 📝 **Note for report:** This section directly maps to the *Model Selection* rubric criterion. Make sure your plot is fully labeled!

# %%
# Step: Set up cross-validator
# YOUR CODE HERE

# %%
# Step: Cross-validate Logistic Regression
# YOUR CODE HERE

# %%
# Step: Cross-validate KNN for multiple k values
# YOUR CODE HERE

# %%
# Step: Plot model selection results (Figure 2)
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 4 — Final Model Estimation
#
# **Steps:**
# - [ ] Train the winning model on the **full dataset** (not just one fold)
# - [ ] Print final accuracy and F1-score
# - [ ] Print a classification report (precision, recall per class)
# - [ ] Plot the confusion matrix (Figure 3)
# - [ ] If using Logistic Regression: plot the feature coefficients to show which features matter most (Figure 4)
#
# > 📝 **Note for report:** The coefficients plot directly supports your hypothesis about lifestyle vs demographic features.

# %%
# Step: Train final model on full data and report accuracy
# YOUR CODE HERE

# %%
# Step: Plot confusion matrix (Figure 3)
# YOUR CODE HERE

# %%
# Step: Plot feature coefficients / importance (Figure 4)
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 5 — Hypothesis Test
#
# **Hypothesis:** Lifestyle features (sleep, exercise, stress) are stronger predictors than demographic features (age, gender) alone.
#
# **Steps:**
# - [ ] Define a **lifestyle-only** feature subset (sleep, exercise, stress, social support)
# - [ ] Define a **demographic-only** feature subset (age, gender)
# - [ ] Train logistic regression on each subset using cross-validation
# - [ ] Compare CV accuracy: lifestyle-only vs demographic-only vs full model
# - [ ] Write a 2–3 sentence interpretation — does the result support your hypothesis?
#
# > 📝 **Note for report:** This comparison directly answers your hypothesis in the Discussion section.

# %%
# Step: Lifestyle-only model
# YOUR CODE HERE

# %%
# Step: Demographic-only model
# YOUR CODE HERE

# %%
# Step: Print comparison table
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 6 — Summary Table
#
# > Fill this in after completing all sections above.
#
# | Model | Features used | CV Accuracy (mean ± std) |
# |---|---|---|
# | Logistic Regression | All | __ |
# | KNN (best k = __) | All | __ |
# | Logistic Regression | Lifestyle only | __ |
# | Logistic Regression | Demographic only | __ |
#
# **Selected final model:** [fill in]
# **Reason for selection:** [fill in]
# **Evidence of overfitting?** [fill in — e.g. KNN k=1 overfits, large k underfits]
# **Hypothesis supported?** [fill in]
